# %%
import pandas as pd
from build_dataset import BuildDataset
from neural_network import NeuralNetwork

# Load the dataset
df = pd.read_csv('heart.csv')

# Preprocess the dataset
X_train, X_test, y_train, y_test = BuildDataset(df)

# Initialize the neural network
input_size = X_train.shape[1]
hidden_layers = [12, 8]
output_size = 1
model = NeuralNetwork(input_size, hidden_layers, output_size)

# Train the neural network
model.train(X_train, y_train.values, epochs=1000, learning_rate=0.01)

# Make predictions
predictions = model.predict(X_test)

# Evaluate model performance
accuracy = np.mean(predictions.flatten() == y_test.values)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 0: cost = 0.25009532002416573
# Epoch 100: cost = 0.24939371448584483
# Epoch 200: cost = 0.2489120627862291
# Epoch 300: cost = 0.24858145023661718
# Epoch 400: cost = 0.24835444795340958
# Epoch 500: cost = 0.24819850695036658
# Epoch 600: cost = 0.24809131763158795
# Epoch 700: cost = 0.24801759282044855
# Epoch 800: cost = 0.24796685425990173
# Epoch 900: cost = 0.24793191558819017
# Accuracy: 58.15%

# %% [markdown]
# I was not satisfied with this accuracy so I felt like using tensorflow to see if I can get a better result

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Load and preprocess the dataset
df = pd.read_csv('heart.csv')

# Preprocess the dataset
X_train, X_test, y_train, y_test = BuildDataset(df)

# Build the TensorFlow model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.3408 - loss: 0.7208 - val_accuracy: 0.4558 - val_loss: 0.6918
# Epoch 2/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5389 - loss: 0.6687 - val_accuracy: 0.5034 - val_loss: 0.6661
# Epoch 3/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5887 - loss: 0.6153 - val_accuracy: 0.5102 - val_loss: 0.6354
# Epoch 4/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6071 - loss: 0.5773 - val_accuracy: 0.6599 - val_loss: 0.6055
# Epoch 5/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7359 - loss: 0.5368 - val_accuracy: 0.7483 - val_loss: 0.5687
# ...
